# %%
a=32j+35j
a
# Out:
# 67j

# %%
type(a)
# Out:
# complex

# %%
s="hit"
id(s)
# Out:
# 1549525064064

# %%
type(s)
# Out:
# str

# %%
s='Tausif Iqbal'
s.upper()
# Out:
# 'TAUSIF IQBAL'

# %%
x='tk12'
x.isdigit()
# Out:
# False

# %%
y="tausifiqbal"
y.isalpha()
# Out:
# True

# %%
s.count('a')
# Out:
# 2

# %%
y=y.replace("tausif","Tausif ")
y
# Out:
# 'Tausif iqbal'

# %%
s=" Tausif "
s.strip()
# Out:
# 'Tausif'

# %%
"""list is mutable where as string is immutable
   mutable is also known as unhashable data type
   Tupple is immutable"""
# Out:
# 'list is mutable'

# %%
ls=[1,2]
ls.append(3)
ls
# Out:
# [1, 2, 3]

# %%
ls.insert(1,3)
ls
# Out:
# [1, 3, 2, 3]

# %%
ls.remove(3)
ls
# Out:
# [1, 2, 3]

# %%
ls.count(3)
# Out:
# 2

# %%
ls.sort(reverse=True)
ls
# Out:
# [3, 3, 2]

# %%
ls.reverse()
ls
# Out:
# [3, 3, 2]

# %%
ls.pop()
ls
# Out:
# [3, 3, 2]

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
dict={
  "a":1,
   "name":"Tausif"
}
dict
# Out:
# {'a': 1, 'name': 'Tausif'}

# %%
dict["a"]
dict.get("namee","error")
# Out:
# 'error'

# %%
dict.keys()
# Out:
# dict_keys(['a', 'name'])

# %% [markdown]
# To overcome error use get method

# %%
dict.values()
# Out:
# dict_values([1, 'Tausif'])

# %%
dict.pop('a')
# Out:
# 1

# %%
dict.items()
# Out:
# dict_items([('name', 'Tausif')])

# %%
s=set()
s.add(1)
s.add(2)
s
# Out:
# {1, 2}

# %%
"""set can only accept immutable values that means data type such as list are not allowed"""

# %%
s1=s.copy() #this is deep copy 
s1
# Out:
# {1, 2}

# %%
s1.pop() 
s1
# Out:
# {2}

# %%
"""shallow copy vs general copy vs deep copy"""

# %%
s1.add(3)
s1
# Out:
# {2, 3}

# %%
s1.remove(2)
s1
# Out:
# {3}

# %%
s1.discard(2)#No error if not found
s1
# Out:
# {3}

# %%
print(10//6)
print(10/6)
# Out:
# 1
# 1.6666666666666667

# %%
2 and 3
# Out:
# 3

# %%
3 and 2
# Out:
# 2

# %%
0 and 3
# Out:
# 0

# %%
3 and 0
# Out:
# 0

# %%
#3 in [5,4,3]
#3 in (5,4)
3 in {5,4,3}
# Out:
# True

# %%
bin(10)
hex(10)
oct(10)
bin(20)
20^30
5<<2
# Out:
# 20

# %%
r=[1,2,3]#values address will be same but list value will be different 
s=[1,2,3]
t=r
r is t
# Out:
# True

# %%
"""All scripting language are programming language but all programming language are not scripting language"""

# %%
x=input("enter your name:")

# %%
x
# Out:
# 'Tausif'

# %%
b=eval(input("enter a value"))

# %%
b
# Out:
# [1, 2, 3]

# %%
type(b)
# Out:
# list

# %%
x=(int)(input("enter first number"))
if x%3==0 and x%5==0:
  print(True)
# Out:
# True

# %%
age=(int)(input("enter your age"))
if(age>=18 and age<=25):
  print("eligibile for vote")
# Out:
# eligibile for vote

# %%
num=(int)(input("enter a number"))
if num>=0:
  print("positive")
else:
  print("negative")
# Out:
# negative

# %%
marks=(int)(input("enter studnet marks"))
if marks>=90:
  print("A")
elif marks>=75:
  print("B")
elif marks>=60:
  print("C")
else:
  print("Fail")
# Out:
# Fail

# %%
ch=(input("enter a character"))
if ch.isupper():
  print("uppercase")
elif ch.islower():
  print("lowercase")
elif ch.isdigit():
  print("digit")
else:
  print("special character")
# Out:
# special character

# %%
exp=eval(input("enter experience"))
pr=eval(input("enter performance rating"))
if(exp>=5):
  if(pr>=4):
    print("20% bonus")
  else:
    print("10% bonus")
else:
  print("no bonus")
# Out:
# no bonus

# %%
num=(int)(input("enter a number"))
if num>=0:
  if(num%2==0):
    print("positive and even")
  else:
    print("positive and odd")
else:
  print("negative")
# Out:
# positive and even

# %%
correctPin=1234
balance=5000
pin=eval(input("enter pin"))
amt=eval(input("enter amount"))
if pin==correctPin:
  if balance>=amt:
    print("Transaction successfull")
  else:
    print("Insufficient Balance")
else:
  print("Invalid PIN")
# Out:
# Insufficient Balance

# %%
s="hello"#slicing never give error even if index out of bond
s[0:1]
s[::2]
s[::-1]
# Out:
# 'olleh'

# %%
"""slicing"""
